# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Pandas Library**

# %%
#how to retrieve information about function
help(pd.DataFrame)
# Out:
# Help on class DataFrame in module pandas.core.frame:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure.
#  |
#  |  Parameters
#  |  ----------
#  |  data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |
#  |      .. versionchanged :: 0.23.0
#  |         If data is a dict, column order follows insertion-order for
#  |         Python 3.6 and later.
#  |
#  |      .. versionchanged :: 0.25.0
#  |         If data is a list of dicts, column order follows insertion-order
#  |         for Python 3.6 and later.
#  |
#  |  index : Index or array-like
# ...

# %% [markdown]
# # **Import dataframe**
# Reading csv file using pandas library

# %%
df=pd.read_csv("/content/drive/My Drive/Kaggle/Titanic/Data/train.csv")
print('Columns :{}'.format(df.columns))
print('-----------')
print('Columns types')
print(df.dtypes)
print('-----------')
print('Check null for each column')
print(df.isnull().sum())
# Out:
# Columns :Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# -----------
# Columns types
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# -----------
# Check null for each column
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
df.tail()
# Out:
#      PassengerId  Survived  Pclass  ...   Fare Cabin  Embarked
# 886          887         0       2  ...  13.00   NaN         S
# 887          888         1       1  ...  30.00   B42         S
# 888          889         0       3  ...  23.45   NaN         S
# 889          890         1       1  ...  30.00  C148         C
# 890          891         0       3  ...   7.75   NaN         Q
#
# [5 rows x 12 columns]

# %%
#summarise each column
df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %%
#unique
df[['Name']].unique()

# %%
#sort
df.sort_values(by='Age')

# %%
#filter dataframe on age value not null
df[df['Age'].isnull()==False]
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   NaN         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   NaN         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 885          886         0       3  ...  29.1250   NaN         Q
# 886          887         0       2  ...  13.0000   NaN         S
# 887          888         1       1  ...  30.0000   B42         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [714 rows x 12 columns]

# %%
df[(df['Age'].isnull()==False) & (df['Pclass']==1)]

# %%
#loc gets rows (or columns) with particular labels from the index.
#df.loc[:1,]#all columns
df.loc[:1,'Name']#first two rows and column Name
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Name: Name, dtype: object

# %%
# gets rows (or columns) at particular positions in the index (so it only takes integers).
#df.iloc[1,4]#index row and column
df.iloc[:1,:4]
# Out:
#    PassengerId  Survived  Pclass                     Name
# 0            1         0       3  Braund, Mr. Owen Harris

# %%
#map function -> used on Series
df['2class']=df['Pclass'].map(lambda x: x*2)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... Cabin Embarked  2class
# 0            1         0       3  ...   NaN        S       6
# 1            2         1       1  ...   C85        C       2
# 2            3         1       3  ...   NaN        S       6
# 3            4         1       1  ...  C123        S       2
# 4            5         0       3  ...   NaN        S       6
#
# [5 rows x 13 columns]

# %%
#apply function->used on Dataframe and Series
def double_class(item):
  return item*2

df['2class_apply']=df[['Pclass','Sex']].apply(lambda x:double_class(x))
df.head()
# Out:
#    PassengerId  Survived  Pclass  ... 2class 2class_apply  2class_applymap
# 0            1         0       3  ...      6            6                6
# 1            2         1       1  ...      2            2                2
# 2            3         1       3  ...      6            6                6
# 3            4         1       1  ...      2            2                2
# 4            5         0       3  ...      6            6                6
#
# [5 rows x 15 columns]

# %% [markdown]
# #**Matplotlib Library: module: PyPlot & Seaborn**

# %%
#https://matplotlib.org/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py
fig = plt.figure()  # an empty figure with no axes
fig.suptitle('No axes on this figure')  # Add a title so we know which it is

fig, ax_lst = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes

# %%
fig=plt.figure(figsize=(10,10))

fig.suptitle('Quickview Plots')
fig,ax=plt.subplots(2,2,sharex=True,figsize=(15,10))#ax corresponds to the box which includes the plot

df['Age'][df['Age'].isnull()==False].plot(kind='line',
                                          ax=ax[0,0],linestyle='--',
                                          linewidth=3,
                                          color='r',
                                          marker='o')
ax[0,0].set_title("Lineplot")

df['Age'][df['Age'].isnull()==False].plot(kind='hist',
                                                  ax=ax[0,1],color='g')
ax[0,1].set_title("Histogram")

df['Age'][df['Age'].isnull()==False].plot(kind='bar',
                                          ax=ax[1,0],color='b')
ax[1,0].set_title("Barplot")

df['Age'][df['Age'].isnull()==False].plot(kind='area',
                                          ax=ax[1,1])
ax[1,1].set_title("Area")

plt.show()

# %% [markdown]
# # **LINEPLOT**

# %%
fig=plt.figure(figsize=(10,6))


plt.title('Fare Plot')
plt.xlabel('Freq')
plt.ylabel('Fare_Value')

df['Fare'].plot(kind='line',
                color='r',
                alpha=0.6,
                linewidth=2,
                marker='o',
                linestyle='--')
plt.ylim(0,300)
plt.xlim(0,50)

plt.show()

# %%
f, axes = plt.subplots(2, 1,figsize=(10,10))#numrows,numcols
f.suptitle('Distribution')
sns.lineplot(x='Age', y="Fare", hue="Pclass",
data=df,ax=axes[0])

sns.lineplot(x='Age', y="Fare", hue="Sex",
data=df,ax=axes[1])
plt.show()

# %% [markdown]
# # **BARPLOT**

# %%
figure=plt.figure(figsize=(10,6))
df['Survived'].value_counts().plot(kind='bar',
                color=['r','b'],
                alpha=0.5)
plt.title('Survived Bar')
plt.show()

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(data=df, x='Pclass',hue='Sex', palette='magma')
plt.title('PCLASS/SEX')
plt.show()

# %% [markdown]
# # **Distribution**

# %%
fig=plt.figure(figsize=(10,6))
plt.title('Distribution')
sns.distplot(df['Fare'])
plt.show()

# %%
fig=plt.figure(figsize=(10,10))
df_subplot=df[['Fare','Pclass','SibSp','Parch']]
i=1
for item in df_subplot:
  plt.subplot(2,2,i,title=item)
  sns.distplot(df_subplot[item])
  i=i+1
plt.show()

# %% [markdown]
# # **Area**

# %%
plt.figure(figsize=(10,5))

df['Fare2']=df['Fare'].map(lambda x: x*1.2)

df[['Fare','Fare2']].plot(kind='area',colors=['red','yellow',],alpha=0.5)
plt.title('Area')

plt.xlabel('Fare')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/core.py:203: UserWarning: 'colors' is being deprecated. Please use 'color'instead of 'colors'
#   "'colors' is being deprecated. Please use 'color'"

# %% [markdown]
# # **Histogram**

# %%
plt.figure(figsize=(10,5))
df['Fare'].plot(kind='hist',edgecolor='white',alpha=0.4,bins=10)

plt.show()

# %% [markdown]
# # **Boxplot**

# %%
plt.figure(figsize=(10,5))


plt.subplot(1,2,1)#row,col,position
df['Fare'].plot(kind='box',color='blue')


plt.subplot(1,2,2)#row,col,position
df['Age'][df['Age'].isnull()==False].plot(kind='box',color='green')

# %%
sns.boxplot(x='Survived',y='Age',hue='Pclass',data=df[df['Age'].isnull()==False])

# %% [markdown]
# # **Piechart**

# %%
df_test_sum=df[['PassengerId','Pclass','Sex']].groupby(['Pclass','Sex']).count().reset_index()
print(df_test_sum)
label_list=df_test_sum[['Pclass','Sex']].values
print(label_list)
label_list_str=[str(x) for x in label_list]

df_test_sum.plot.pie(y=['PassengerId'],
                     #colors=['orange','lightblue','lightgreen','red','gold','green'],
                     shadow=True,
                     startangle=90,#explode=(0.1,0,0,0,0,0),#explode first slice
                     wedgeprops={"edgecolor":"k",'linewidth': 1, 'linestyle': '-', 'antialiased': True},
                     subplots=True,
                     figsize=(12,8)
                 )
plt.title('Sex')
plt.legend(label_list_str)
plt.show()
# Out:
#    Pclass     Sex  PassengerId
# 0       1  female           94
# 1       1    male          122
# 2       2  female           76
# 3       2    male          108
# 4       3  female          144
# 5       3    male          347
# [[1 'female']
#  [1 'male']
#  [2 'female']
#  [2 'male']
#  [3 'female']
#  [3 'male']]

# %% [markdown]
# # **Heatmap Correlation**

# %%
#Pearson correlation
fig=plt.figure(figsize=(10,6))
fig.suptitle('Pearson Correlation')
sns.heatmap(df[['Age','Pclass','Survived']].corr())
plt.show()

# %% [markdown]
# # **Regression Plot**

# %%
plt.figure(figsize=(10,6))
plt.title('Regression')
sns.regplot(x='Fare',y='Age',data=df[df['Age'].isnull()==False],marker='+',color='red')
plt.show()

# %% [markdown]
# # **Intermediate**

# %%
from sklearn.datasets import load_iris

# %%
data=load_iris()
df_iris=pd.DataFrame(data=data.data,columns=data.feature_names)
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df_iris_copy=df_iris.copy()

# %%
df_iris.concat(df_iris_copy)

# %%
pd.merge(df_iris, df_iris_copy, on='petal width (cm)')

# %%
#applymap used on dataframe ONLY
df_iris['sepal width (cm)']=df_iris.applymap(lambda x: x*2)
df_iris.head()
# Out:
#    PassengerId  Survived  Pclass  ... 2class 2class_apply  2class_applymap
# 0            1         0       3  ...      6            6                2
# 1            2         1       1  ...      2            2                4
# 2            3         1       3  ...      6            6                6
# 3            4         1       1  ...      2            2                8
# 4            5         0       3  ...      6            6               10
#
# [5 rows x 15 columns]

# %%
df_c_s_p=df[['Pclass','Sex','PassengerId']].groupby(['Pclass','Sex'],as_index=False).count()
print('Count passengers per PClass')
print(df_c_s_p)
print('---------')
print('Pivoting new dataframe')
df_pivot = df_c_s_p.pivot(columns='Pclass',index='Sex')
print(df_pivot)
print('---------')
df_pivot.plot(kind='bar',stacked=True,legend=True,title='Sex/PClass distribution')
plt.show()
# Out:
# Count passengers per PClass
#    Pclass     Sex  PassengerId
# 0       1  female           94
# 1       1    male          122
# 2       2  female           76
# 3       2    male          108
# 4       3  female          144
# 5       3    male          347
# ---------
# Pivoting new dataframe
#        PassengerId
# Pclass           1    2    3
# Sex
# female          94   76  144
# male           122  108  347
# ---------

# %%
#calculate percentage 
df_c_s_p['Tot_Sex']=df_c_s_p[['Sex','PassengerId']].groupby(['Sex']).transform('sum')
df_c_s_p['Perc_Sex']=df_c_s_p['PassengerId']/df_c_s_p['Tot_Sex']
print('Adding percentage Sex/Class')
print(df_c_s_p)
print('---------')
df_pivot = df_c_s_p.pivot(columns='Pclass',index='Sex',values='Perc_Sex')
#plot it
print('Percentage Sex/Class')
print(df_pivot)
print('---------')

df_pivot.plot(kind='bar',stacked=True,legend=True,title='Percentage Sex/PClass',figsize=(10,6))
plt.show()
# Out:
# Adding percentage Sex/Class
#    Pclass     Sex  PassengerId  Tot_Sex  Perc_Sex
# 0       1  female           94      314  0.299363
# 1       1    male          122      577  0.211438
# 2       2  female           76      314  0.242038
# 3       2    male          108      577  0.187175
# 4       3  female          144      314  0.458599
# 5       3    male          347      577  0.601386
# ---------
# Percentage Sex/Class
# Pclass         1         2         3
# Sex
# female  0.299363  0.242038  0.458599
# male    0.211438  0.187175  0.601386
# ---------

# %%
plt.figure(figsize=(10,6))
plt.plot(df_iris,marker='s')

plt.legend(loc='best')

plt.title("Iris")

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(10,6))

plt.plot(df_iris['sepal length (cm)'],color="r",label="sepal length (cm)",marker='o')
plt.plot(df_iris['sepal width (cm)'],color='b',label="sepal width (cm)",marker='h')
plt.plot(df_iris['petal length (cm)'],color='g',label="petal length (cm)",marker='s')
plt.plot(df_iris['petal width (cm)'],color='y',label="petal width (cm)",marker='h')

plt.legend(loc='best')

plt.title("Iris")

plt.show()
